# %% [markdown]
# # 1 The Spark Session
#
# ## 1.1 Automatic initialization

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#             <div>
#                 <p><b>SparkContext</b></p>
#                 <p><a href="https://dbc-1029f43c-feab.cloud.databricks.com#/setting/clusters/0508-164224-fores138/sparkUi">Spark UI</a></p>
#                 <dl>
#                   <dt>Version</dt><dd><code>v2.4.5</code></dd>
#                   <dt>AppName</dt><dd><code>Databricks Shell</code></dd>
#                   <dt>Master</dt><dd><code>spark://10.45.247.16:7077</code></dd>
#                 </dl>
#             </div>
#
#             </div>

# %% [markdown]
# ## 1.2 Spark progress bar intergation

# %%
df = spark.read.csv("/databricks-datasets/bikeSharing/data-001/hour.csv", inferSchema=True, header=True)
# Out:
# HBox(children=(Button(icon='arrow-circle-right', style=ButtonStyle(), tooltip='Toggle progress bar', _dom_clas…

# %%
df.filter(df.holiday > 0)
# Out:
# HBox(children=(Button(icon='arrow-circle-right', style=ButtonStyle(), tooltip='Toggle progress bar', _dom_clas…
# +-------+-------------------+------+---+----+---+-------+-------+----------+----------+----+------+----+---------+------+----------+---+
# |instant|             dteday|season| yr|mnth| hr|holiday|weekday|workingday|weathersit|temp| atemp| hum|windspeed|casual|registered|cnt|
# +-------+-------------------+------+---+----+---+-------+-------+----------+----------+----+------+----+---------+------+----------+---+
# |    373|2011-01-17 00:00:00|     1|  0|   1|  0|      1|      1|         0|         2| 0.2| 0.197|0.47|   0.2239|     1|        16| 17|
# |    374|2011-01-17 00:00:00|     1|  0|   1|  1|      1|      1|         0|         2| 0.2| 0.197|0.44|    0.194|     1|        15| 16|
# |    375|2011-01-17 00:00:00|     1|  0|   1|  2|      1|      1|         0|         2|0.18|0.1667|0.43|   0.2537|     0|         8|  8|
# |    376|2011-01-17 00:00:00|     1|  0|   1|  3|      1|      1|         0|         2|0.18|0.1818|0.43|    0.194|     0|         2|  2|
# |    377|2011-01-17 00:00:00|     1|  0|   1|  4|      1|      1|         0|         2|0.18| 0.197|0.43|   0.1343|     1|         2|  3|
# |    378|2011-01-17 00:00:00|     1|  0|   1|  5|      1|      1|         0|         2|0.18| 0.197|0.43|   0.1642|     0|         1|  1|
# |    379|2011-01-17 00:00:00|     1|  0|   1|  6|      1|      1|         0|         2|0.18|0.1818|0.43|    0.194|     0|         5|  5|
# |    380|2011-01-17 00:00:00|     1|  0|   1|  7|      1|      1|         0|         2|0.16|0.1818| 0.5|   0.1343|     4|         9| 13|
# |    381|2011-01-17 00:00:00|     1|  0|   1|  8|      1|      1|         0|         2|0.16|0.1515|0.47|   0.2239|     3|        30| 33|
# |    382|2011-01-17 00:00:00|     1|  0|   1|  9|      1|      1|         0|         2|0.16|0.1515|0.47|   0.2239|     8|        39| 47|
# |    383|2011-01-17 00:00:00|     1|  0|   1| 10|      1|      1|         0|         2|0.16|0.1515| 0.5|   0.2537|     7|        50| 57|
# |    384|2011-01-17 00:00:00|     1|  0|   1| 11|      1|      1|         0|         2|0.16|0.1515|0.55|    0.194|     9|        55| 64|
# |    385|2011-01-17 00:00:00|     1|  0|   1| 12|      1|      1|         0|         2|0.18| 0.197|0.47|   0.1343|    10|        70| 80|
# |    386|2011-01-17 00:00:00|     1|  0|   1| 13|      1|      1|         0|         2|0.18| 0.197|0.47|   0.1343|    13|        80| 93|
# |    387|2011-01-17 00:00:00|     1|  0|   1| 14|      1|      1|         0|         2|0.18|0.2121|0.43|   0.1045|    12|        74| 86|
# |    388|2011-01-17 00:00:00|     1|  0|   1| 15|      1|      1|         0|         2| 0.2|0.2121|0.47|   0.1642|    21|        72| 93|
# |    389|2011-01-17 00:00:00|     1|  0|   1| 16|      1|      1|         0|         2| 0.2|0.2121|0.47|   0.1642|     6|        76| 82|
# |    390|2011-01-17 00:00:00|     1|  0|   1| 17|      1|      1|         0|         1| 0.2| 0.197|0.51|    0.194|     4|        67| 71|
# |    391|2011-01-17 00:00:00|     1|  0|   1| 18|      1|      1|         0|         2|0.18|0.1667|0.55|   0.2537|     7|        85| 92|
# |    392|2011-01-17 00:00:00|     1|  0|   1| 19|      1|      1|         0|         3|0.18|0.1818|0.59|    0.194|     2|        58| 60|
# +-------+-------------------+------+---+----+---+-------+-------+----------+----------+----+------+----+---------+------+----------+---+
# only showing top 20 rows

# %% [markdown]
# # 2 Browsers
#
# ## 2.1 DBFS Browser

# %%
dbbrowser.dbfs(path= "/")
# Out:
# VBox(children=(HBox(children=(Button(icon='refresh', layout=Layout(width='40px'), style=ButtonStyle()), Button…

# %% [markdown]
# ## 2.2 Database Browser

# %%
dbbrowser.databases()
# Out:
# VBox(children=(HBox(children=(VBox(children=(Button(icon='refresh', layout=Layout(width='40px'), style=ButtonS…

# %% [markdown]
# # 3 dbutils support

# %%
dbutils.help()
# Out:
#         This module provides a subset of the DBUtils tools working for Jupyterlab Integration
#         <br/><br/>
#         <b>fs: DbfsUtils</b> -&gt; Manipulates the Databricks filesystem (DBFS) from the console
#         <br/>
#         <b>secrets: SecretUtils</b> -&gt; Provides utilities for leveraging secrets within notebooks
#         <br/>
#         <b>notebook: NotebookUtils</b> -&gt; Utilities for the control flow of a notebook (EXPERIMENTAL)

# %% [markdown]
# ## 3.1 Module `secrets`

# %%
dbutils.secrets.listScopes()
# Out:
# [SecretScope(name='dbjl-pytest'),
#  SecretScope(name='dbjl-pytest2'),
#  SecretScope(name='scala-creds')]

# %%
dbutils.secrets.list("dbjl-pytest")
# Out:
# [SecretMetadata(key='pytest-key')]

# %% [markdown]
# ### Note: Secrets are not redacted in Jupyterlab Integration!

# %%
dbutils.secrets.get("dbjl-pytest", "pytest-key")
# Out:
# 'databrickslabs-jupyterlab'

# %% [markdown]
# ## 3.2 Module `fs`

# %%
dbutils.fs.ls("/data")
# Out:
# [FileInfo(path='dbfs:/data/airbnb/', name='airbnb/', size=0),
#  FileInfo(path='dbfs:/data/bank.csv', name='bank.csv', size=461474),
#  FileInfo(path='dbfs:/data/covtype.csv', name='covtype.csv', size=141875378),
#  FileInfo(path='dbfs:/data/covtype.parquet/', name='covtype.parquet/', size=0),
#  FileInfo(path='dbfs:/data/digits/', name='digits/', size=0),
#  FileInfo(path='dbfs:/data/mnist/', name='mnist/', size=0)]

# %%
# %fs ls /FileStore
# Out:
# List directory '/FileStore':
#
# FileInfo(path='dbfs:/FileStore/derby.log', name='derby.log', size=732)
# FileInfo(path='dbfs:/FileStore/import-stage/', name='import-stage/', size=0)
# FileInfo(path='dbfs:/FileStore/initialization.ipynb', name='initialization.ipynb', size=915)
# FileInfo(path='dbfs:/FileStore/jars/', name='jars/', size=0)
# FileInfo(path='dbfs:/FileStore/jupyter_debug/', name='jupyter_debug/', size=0)
# FileInfo(path='dbfs:/FileStore/plots/', name='plots/', size=0)
# FileInfo(path='dbfs:/FileStore/scripts/', name='scripts/', size=0)

# %% [markdown]
# ## 3.3 Module `notebook`

# %% [markdown]
# ### 3.3.1 Run external notebooks
#
# - Notebooks to be run need to be copied to the remote filesystem, e.g. `/dbfs/home/<username>/...` with `/dbfs/` being the posix pount of the dbfs filesystem.
# Notebooks can be copied to remote dbfs with the `databricks` utility, e.g.
#
#     `databricks --profile demo fs cp initialize.ipynb /dbfs/home/bernhard/`
#
# - Since this notebook runs on the remote machine, this cannot be done in this notebook

# %%
test = {"a": 42, "l": [0, 1, 1, 2, 3, 5, 8]}

# %%
to_json(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-f14155eaa5de> in <module>
# ----> 1 to_json(test)
#
# NameError: name 'to_json' is not defined

# %%
dbutils.notebook.run("/FileStore/initialization")
# Out:
# Running '/dbfs/FileStore/initialization.ipynb'
# Successfully initialized

# %%
to_json(test)
# Out:
# '{"a": 42, "l": [0, 1, 1, 2, 3, 5, 8]}'

# %%
# %run /dbfs/FileStore/initialization.ipynb
# Out:
# Successfully initialized

# %% [markdown]
# ### 3.3.2 Stop "run all" execution at defined locations in the notebook

# %%
dbutils.notebook.exit("test")
# Out:
# Notebook exited: test

# %% [markdown]
# # 4 Multi Language support

# %% [markdown]
# ## 4.1 SQL integration
#
# Uses a `spark.sql` wrapper:
# - no support of autocompletion

# %%
df.createOrReplaceTempView("bikes")

# %%
# %%sql
# show tables
# Out:
# +--------+------------+-----------+
# |database|   tableName|isTemporary|
# +--------+------------+-----------+
# | default|exampletable|      false|
# |        |       bikes|       true|
# +--------+------------+-----------+

# %%
# %%sql
# select * from bikes
# Out:
# HBox(children=(Button(icon='arrow-circle-right', style=ButtonStyle(), tooltip='Toggle progress bar', _dom_clas…
# +-------+-------------------+------+---+----+---+-------+-------+----------+----------+----+------+----+---------+------+----------+---+
# |instant|             dteday|season| yr|mnth| hr|holiday|weekday|workingday|weathersit|temp| atemp| hum|windspeed|casual|registered|cnt|
# +-------+-------------------+------+---+----+---+-------+-------+----------+----------+----+------+----+---------+------+----------+---+
# |      1|2011-01-01 00:00:00|     1|  0|   1|  0|      0|      6|         0|         1|0.24|0.2879|0.81|      0.0|     3|        13| 16|
# |      2|2011-01-01 00:00:00|     1|  0|   1|  1|      0|      6|         0|         1|0.22|0.2727| 0.8|      0.0|     8|        32| 40|
# |      3|2011-01-01 00:00:00|     1|  0|   1|  2|      0|      6|         0|         1|0.22|0.2727| 0.8|      0.0|     5|        27| 32|
# |      4|2011-01-01 00:00:00|     1|  0|   1|  3|      0|      6|         0|         1|0.24|0.2879|0.75|      0.0|     3|        10| 13|
# |      5|2011-01-01 00:00:00|     1|  0|   1|  4|      0|      6|         0|         1|0.24|0.2879|0.75|      0.0|     0|         1|  1|
# |      6|2011-01-01 00:00:00|     1|  0|   1|  5|      0|      6|         0|         2|0.24|0.2576|0.75|   0.0896|     0|         1|  1|
# |      7|2011-01-01 00:00:00|     1|  0|   1|  6|      0|      6|         0|         1|0.22|0.2727| 0.8|      0.0|     2|         0|  2|
# |      8|2011-01-01 00:00:00|     1|  0|   1|  7|      0|      6|         0|         1| 0.2|0.2576|0.86|      0.0|     1|         2|  3|
# |      9|2011-01-01 00:00:00|     1|  0|   1|  8|      0|      6|         0|         1|0.24|0.2879|0.75|      0.0|     1|         7|  8|
# |     10|2011-01-01 00:00:00|     1|  0|   1|  9|      0|      6|         0|         1|0.32|0.3485|0.76|      0.0|     8|         6| 14|
# |     11|2011-01-01 00:00:00|     1|  0|   1| 10|      0|      6|         0|         1|0.38|0.3939|0.76|   0.2537|    12|        24| 36|
# |     12|2011-01-01 00:00:00|     1|  0|   1| 11|      0|      6|         0|         1|0.36|0.3333|0.81|   0.2836|    26|        30| 56|
# |     13|2011-01-01 00:00:00|     1|  0|   1| 12|      0|      6|         0|         1|0.42|0.4242|0.77|   0.2836|    29|        55| 84|
# |     14|2011-01-01 00:00:00|     1|  0|   1| 13|      0|      6|         0|         2|0.46|0.4545|0.72|   0.2985|    47|        47| 94|
# |     15|2011-01-01 00:00:00|     1|  0|   1| 14|      0|      6|         0|         2|0.46|0.4545|0.72|   0.2836|    35|        71|106|
# |     16|2011-01-01 00:00:00|     1|  0|   1| 15|      0|      6|         0|         2|0.44|0.4394|0.77|   0.2985|    40|        70|110|
# |     17|2011-01-01 00:00:00|     1|  0|   1| 16|      0|      6|         0|         2|0.42|0.4242|0.82|   0.2985|    41|        52| 93|
# |     18|2011-01-01 00:00:00|     1|  0|   1| 17|      0|      6|         0|         2|0.44|0.4394|0.82|   0.2836|    15|        52| 67|
# |     19|2011-01-01 00:00:00|     1|  0|   1| 18|      0|      6|         0|         3|0.42|0.4242|0.88|   0.2537|     9|        26| 35|
# |     20|2011-01-01 00:00:00|     1|  0|   1| 19|      0|      6|         0|         3|0.42|0.4242|0.88|   0.2537|     6|        31| 37|
# +-------+-------------------+------+---+----+---+-------+-------+----------+----------+----+------+----+---------+------+----------+---+
# only showing top 20 rows

# %% [markdown]
# ## 4.2 Scala integration
#
# Uses REST API 1.2:
# - no Spark progress bar
# - no support of autocompletion
# - no incremental outputs (cell will be executed as block and all output appears at the end of execution

# %%
spark.sparkContext.applicationId
# Out:
# 'app-20200527070031-0000'

# %%
# %%scala
# spark.sparkContext.applicationId
# Out:
#
# res0: String = app-20200527070031-0000

# %%
# %%scala
# val a = 42
# a
# Out:
#
# a: Int = 42
# res1: Int = 42

# %%
# %%scala
# spark.read.option("header", "true").csv("/databricks-datasets/bikeSharing/data-001/hour.csv")
# Out:
#
# res2: org.apache.spark.sql.DataFrame = [instant: string, dteday: string ... 15 more fields]

# %%
# %%scala
# display(spark.read.option("header", "true").csv("/databricks-datasets/bikeSharing/data-001/hour.csv"))
# Out:
#     instant      dteday season yr mnth  hr holiday weekday workingday  \
# 0         1  2011-01-01      1  0    1   0       0       6          0
# 1         2  2011-01-01      1  0    1   1       0       6          0
# 2         3  2011-01-01      1  0    1   2       0       6          0
# 3         4  2011-01-01      1  0    1   3       0       6          0
# 4         5  2011-01-01      1  0    1   4       0       6          0
# 5         6  2011-01-01      1  0    1   5       0       6          0
# 6         7  2011-01-01      1  0    1   6       0       6          0
# 7         8  2011-01-01      1  0    1   7       0       6          0
# 8         9  2011-01-01      1  0    1   8       0       6          0
# 9        10  2011-01-01      1  0    1   9       0       6          0
# 10       11  2011-01-01      1  0    1  10       0       6          0
# 11       12  2011-01-01      1  0    1  11       0       6          0
# 12       13  2011-01-01      1  0    1  12       0       6          0
# 13       14  2011-01-01      1  0    1  13       0       6          0
# 14       15  2011-01-01      1  0    1  14       0       6          0
# 15       16  2011-01-01      1  0    1  15       0       6          0
# 16       17  2011-01-01      1  0    1  16       0       6          0
# 17       18  2011-01-01      1  0    1  17       0       6          0
# 18       19  2011-01-01      1  0    1  18       0       6          0
# 19       20  2011-01-01      1  0    1  19       0       6          0
# 20       21  2011-01-01      1  0    1  20       0       6          0
# 21       22  2011-01-01      1  0    1  21       0       6          0
# 22       23  2011-01-01      1  0    1  22       0       6          0
# 23       24  2011-01-01      1  0    1  23       0       6          0
# 24       25  2011-01-02      1  0    1   0       0       0          0
# 25       26  2011-01-02      1  0    1   1       0       0          0
# 26       27  2011-01-02      1  0    1   2       0       0          0
# 27       28  2011-01-02      1  0    1   3       0       0          0
# 28       29  2011-01-02      1  0    1   4       0       0          0
# 29       30  2011-01-02      1  0    1   6       0       0          0
# ..      ...         ...    ... ..  ...  ..     ...     ...        ...
# 970     971  2011-02-13      1  0    2   1       0       0          0
# 971     972  2011-02-13      1  0    2   2       0       0          0
# 972     973  2011-02-13      1  0    2   3       0       0          0
# 973     974  2011-02-13      1  0    2   4       0       0          0
# 974     975  2011-02-13      1  0    2   6       0       0          0
# 975     976  2011-02-13      1  0    2   7       0       0          0
# 976     977  2011-02-13      1  0    2   8       0       0          0
# 977     978  2011-02-13      1  0    2   9       0       0          0
# 978     979  2011-02-13      1  0    2  10       0       0          0
# 979     980  2011-02-13      1  0    2  11       0       0          0
# 980     981  2011-02-13      1  0    2  12       0       0          0
# 981     982  2011-02-13      1  0    2  13       0       0          0
# 982     983  2011-02-13      1  0    2  14       0       0          0
# 983     984  2011-02-13      1  0    2  15       0       0          0
# 984     985  2011-02-13      1  0    2  16       0       0          0
# 985     986  2011-02-13      1  0    2  17       0       0          0
# 986     987  2011-02-13      1  0    2  18       0       0          0
# 987     988  2011-02-13      1  0    2  19       0       0          0
# 988     989  2011-02-13      1  0    2  20       0       0          0
# 989     990  2011-02-13      1  0    2  21       0       0          0
# 990     991  2011-02-13      1  0    2  22       0       0          0
# 991     992  2011-02-13      1  0    2  23       0       0          0
# 992     993  2011-02-14      1  0    2   0       0       1          1
# 993     994  2011-02-14      1  0    2   1       0       1          1
# 994     995  2011-02-14      1  0    2   2       0       1          1
# 995     996  2011-02-14      1  0    2   3       0       1          1
# 996     997  2011-02-14      1  0    2   4       0       1          1
# 997     998  2011-02-14      1  0    2   5       0       1          1
# 998     999  2011-02-14      1  0    2   6       0       1          1
# 999    1000  2011-02-14      1  0    2   7       0       1          1
#
#     weathersit  temp   atemp   hum windspeed casual registered  cnt
# 0            1  0.24  0.2879  0.81         0      3         13   16
# 1            1  0.22  0.2727   0.8         0      8         32   40
# 2            1  0.22  0.2727   0.8         0      5         27   32
# 3            1  0.24  0.2879  0.75         0      3         10   13
# 4            1  0.24  0.2879  0.75         0      0          1    1
# 5            2  0.24  0.2576  0.75    0.0896      0          1    1
# 6            1  0.22  0.2727   0.8         0      2          0    2
# 7            1   0.2  0.2576  0.86         0      1          2    3
# 8            1  0.24  0.2879  0.75         0      1          7    8
# 9            1  0.32  0.3485  0.76         0      8          6   14
# 10           1  0.38  0.3939  0.76    0.2537     12         24   36
# 11           1  0.36  0.3333  0.81    0.2836     26         30   56
# 12           1  0.42  0.4242  0.77    0.2836     29         55   84
# 13           2  0.46  0.4545  0.72    0.2985     47         47   94
# 14           2  0.46  0.4545  0.72    0.2836     35         71  106
# 15           2  0.44  0.4394  0.77    0.2985     40         70  110
# 16           2  0.42  0.4242  0.82    0.2985     41         52   93
# 17           2  0.44  0.4394  0.82    0.2836     15         52   67
# 18           3  0.42  0.4242  0.88    0.2537      9         26   35
# 19           3  0.42  0.4242  0.88    0.2537      6         31   37
# 20           2   0.4  0.4091  0.87    0.2537     11         25   36
# 21           2   0.4  0.4091  0.87     0.194      3         31   34
# 22           2   0.4  0.4091  0.94    0.2239     11         17   28
# 23           2  0.46  0.4545  0.88    0.2985     15         24   39
# 24           2  0.46  0.4545  0.88    0.2985      4         13   17
# 25           2  0.44  0.4394  0.94    0.2537      1         16   17
# 26           2  0.42  0.4242     1    0.2836      1          8    9
# 27           2  0.46  0.4545  0.94     0.194      2          4    6
# 28           2  0.46  0.4545  0.94     0.194      2          1    3
# 29           3  0.42  0.4242  0.77    0.2985      0          2    2
# ..         ...   ...     ...   ...       ...    ...        ...  ...
# 970          1   0.2  0.2273  0.59    0.0896      1         23   24
# 971          2   0.2  0.2273  0.75    0.0896      1         19   20
# 972          2   0.2  0.2273  0.69    0.1045      4          8   12
# 973          2   0.2  0.2121  0.69    0.1642      0          2    2
# 974          2   0.2  0.2121  0.69    0.1343      2          3    5
# 975          2  0.22  0.2727  0.55         0      0          3    3
# 976          2  0.22  0.2273  0.64     0.194      1         11   12
# 977          2  0.24  0.2273   0.6    0.2239     12         35   47
# 978          1   0.3  0.2727  0.45    0.3284     19         86  105
# 979          1  0.32  0.2879  0.39    0.4478     26         86  112
# 980          1  0.36  0.3182  0.32    0.4627     58         94  152
# 981          1  0.38  0.3939  0.29    0.3582     62         92  154
# 982          2   0.4  0.4091   0.3    0.4179     51        110  161
# 983          2   0.4  0.4091   0.3    0.2985     40        122  162
# 984          2  0.42  0.4242  0.28    0.3284     28        106  134
# 985          1  0.42  0.4242  0.28    0.3284     30         95  125
# 986          1   0.4  0.4091  0.32    0.2985     17         78   95
# 987          1   0.4  0.4091  0.35    0.2836     11         50   61
# 988          1   0.4  0.4091  0.35    0.3284     15         32   47
# 989          1   0.4  0.4091  0.35    0.3582      6         45   51
# 990          1   0.4  0.4091  0.35    0.2985      5         31   36
# 991          1   0.4  0.4091  0.35    0.3582      3         27   30
# 992          1  0.38  0.3939  0.37    0.3582      3          8   11
# 993          1  0.38  0.3939  0.37    0.3582      1          6    7
# 994          1  0.36  0.3333   0.4    0.2985      0          2    2
# 995          1  0.34  0.3182  0.46    0.2239      1          1    2
# 996          1  0.32   0.303  0.53    0.2836      0          2    2
# 997          1  0.32   0.303  0.53    0.2836      0          3    3
# 998          1  0.34   0.303  0.46    0.2985      1         25   26
# 999          1  0.34   0.303  0.46    0.2985      2         96   98
#
# [1000 rows x 17 columns]
# Data truncated, more than 1000 rows
