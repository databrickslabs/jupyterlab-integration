# %% [markdown]
# **Downloaded by Databrickslabs Jupyterlab**

# %%
# %scala add-secrets-scope add-pat-key

# %%
a = 42

# %%
# %%sql
#
# use default

# %%
# %%sql
#
# select *
# from iris
# where speal_width > 0.8

# %%
# %%sql
#
#
# use default

# %%
# %%sql
#
# select *
# from iris
# where speal_width < 0.8

# %%
# %%scala
#
# val result = sc.range(0,10).collect()
